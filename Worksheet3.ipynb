# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/Titanic-Dataset.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
fare =df['Fare']
fare.head()
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: Fare, dtype: float64

# %%
class_age = df[['Pclass', 'Age']]
class_age.head()
# Out:
#    Pclass   Age
# 0       3  22.0
# 1       1  38.0
# 2       3  26.0
# 3       1  35.0
# 4       3  35.0

# %%
survived_gender = df[['Survived', 'Sex']]
survived_gender.head()
# Out:
#    Survived     Sex
# 0         0    male
# 1         1  female
# 2         1  female
# 3         1  female
# 4         0    male

# %%
fare_gt_100 = df[df['Fare']>100][['Fare']]
fare_gt_100.head()
# Out:
#          Fare
# 27   263.0000
# 31   146.5208
# 88   263.0000
# 118  247.5208
# 195  146.5208

# %%
first_class = df[df['Pclass']==1][['Pclass']]
first_class.head()
# Out:
#     Pclass
# 1        1
# 3        1
# 6        1
# 11       1
# 23       1

# %%
female_under_18 = df[df['Sex']=='female'][df['Age']<18][['Sex', 'Age']]
female_under_18.head()
# Out:
# <ipython-input-9-f99f18e12041>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   female_under_18 = df[df['Sex']=='female'][df['Age']<18][['Sex', 'Age']]
#        Sex   Age
# 9   female  14.0
# 10  female   4.0
# 14  female  14.0
# 22  female  15.0
# 24  female   8.0

# %%
embarked_c_or_s = df[(df['Embarked']=='C') | (df['Embarked']=='S')][['Embarked']]#use paranthesis when using operator
embarked_c_or_s.head()
# Out:
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
first_second_class = df[df['Pclass'].isin([1,2])][['Pclass']]#The isin() method checks if the Dataframe contains the specified value(s).
first_second_class.head()
# Out:
#     Pclass
# 1        1
# 3        1
# 6        1
# 9        2
# 11       1

# %%
df['fare_per_year'] =  df['Fare'] / (df['Age'])
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  fare_per_year
# 0      0         A/5 21171   7.2500   NaN        S       0.329545
# 1      0          PC 17599  71.2833   C85        C       1.875876
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0.304808
# ...

# %%
high_fare_age = df[df['fare_per_year']>5][['fare_per_year']]
high_fare_age.head()
# Out:
#     fare_per_year
# 7       10.537500
# 16      14.562500
# 27      13.842105
# 43      13.859733
# 50       5.669643

# %%
high_fare_age_srt = high_fare_age.sort_values(by='fare_per_year', ascending=False)
high_fare_age_srt.head()
# Out:
#      fare_per_year
# 305     164.728261
# 297      75.775000
# 386      46.900000
# 164      39.687500
# 183      39.000000

# %%
result  = df[df['fare_per_year'].isin(high_fare_age_srt['fare_per_year'])][['Name','fare_per_year']]
result = result.sort_values(by='fare_per_year', ascending=False)
result.head()
# Out:
#                                 Name  fare_per_year
# 305   Allison, Master. Hudson Trevor     164.728261
# 297     Allison, Miss. Helen Loraine      75.775000
# 386  Goodwin, Master. Sidney Leonard      46.900000
# 164     Panula, Master. Eino Viljami      39.687500
# 183        Becker, Master. Richard F      39.000000

# %%
df['fare_per_class'] = df['Fare'] / df['Pclass']
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  fare_per_year  \
# 0      0         A/5 21171   7.2500   NaN        S       0.329545
# 1      0          PC 17599  71.2833   C85        C       1.875876
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0.304808
# ...

# %%
adult_males = df[(df['Sex']=='male') & (df['Age']>18)][['Sex', 'Age','fare_per_class']]
adult_males.head()
# Out:
#      Sex   Age  fare_per_class
# 0   male  22.0        2.416667
# 4   male  35.0        2.683333
# 6   male  54.0       51.862500
# 12  male  20.0        2.683333
# 13  male  39.0       10.425000

# %%
adult_males_srt = adult_males.sort_values(by='fare_per_class', ascending=False)
adult_males_srt.head()
# Out:
#       Sex   Age  fare_per_class
# 679  male  36.0        512.3292
# 737  male  35.0        512.3292
# 27   male  19.0        263.0000
# 438  male  64.0        263.0000
# 118  male  24.0        247.5208

# %%
result = df[df['fare_per_class'].isin(adult_males_srt['fare_per_class'])][['Name','Age','fare_per_class']]
result = result.sort_values(by='fare_per_class', ascending=False)
result.head()
# Out:
#                                    Name   Age  fare_per_class
# 679  Cardeza, Mr. Thomas Drake Martinez  36.0        512.3292
# 258                    Ward, Miss. Anna  35.0        512.3292
# 737              Lesurer, Mr. Gustave J  35.0        512.3292
# 438                   Fortune, Mr. Mark  64.0        263.0000
# 27       Fortune, Mr. Charles Alexander  19.0        263.0000

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  fare_per_year  \
# 0      0         A/5 21171   7.2500   NaN        S       0.329545
# 1      0          PC 17599  71.2833   C85        C       1.875876
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0.304808
# ...

# %%
total_fare = df['Fare'].sum()
total_fare
# Out:
# 28693.9493

# %%
fare_proportion_firstclass = total_firstclass_fare / total_fare
fare_proportion_firstclass
# Out:
# 0.6334928771899656

# %%
total_secondclass_fare = df[df['Pclass']==2]['Fare'].sum()
total_secondclass_fare
# Out:
# 3801.8417

# %%
fare_proportion_secondclass = total_secondclass_fare / total_fare
fare_proportion_secondclass
# Out:
# 0.1324962855496507

# %%
total_thirdclass_fare = df[df['Pclass']==3]['Fare'].sum()
total_thirdclass_fare
# Out:
# 6714.6951

# %%
fare_proportion_thirdclass = total_thirdclass_fare / total_fare
fare_proportion_thirdclass
# Out:
# 0.23401083726038366

# %%
def cat_age(age):
    if age < 18:
        return 'child'
    elif age < 65:
        return 'adult'
    else:
        return 'senior'

df['age_group'] = df['Age'].apply(cat_age)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  fare_per_year  \
# 0      0         A/5 21171   7.2500   NaN        S       0.329545
# 1      0          PC 17599  71.2833   C85        C       1.875876
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0.304808
# ...

# %%
total_passengers = df['PassengerId'].count()
total_passengers
# Out:
# 891

# %%
df['age_group'].value_counts()
# Out:
# age_group
# adult     590
# senior    188
# child     113
# Name: count, dtype: int64

# %%
adult_proportion = df['age_group'].value_counts()['adult'] / total_passengers
print(adult_proportion*100)
# Out:
# 66.21773288439955

# %%
senior_proportion = df['age_group'].value_counts()['senior']/total_passengers
print(senior_proportion*100)
# Out:
# 21.099887766554435

# %%
child_proportion = df['age_group'].value_counts()['child']/total_passengers
print(child_proportion*100)
# Out:
# 12.682379349046016

# %%
66.21773288439955+21.099887766554435+12.682379349046016
# Out:
# 100.0
